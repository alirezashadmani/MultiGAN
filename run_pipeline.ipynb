# %% [markdown]
# # Multi-GAN Runner
#
# This notebook allows you to train and evaluate the `multi_gan` architecture locally or on a cloud virtual machine without hardcoded paths or forced Colab setups.

# %% [markdown]
# ## 1. Setup Environment
# Install the local `multi_gan` package so Python can resolve imports like `from multi_gan.losses import ...`

# %%
# !pip install -e .

# %% [markdown]
# ## 2. Train the Model
# You can trigger the training via the orchestrator script. This leverages `sacred` configs under the hood.
#
# *By default, it will save artifacts to a local `./data/output/multi_gan` directory instead of trying to write to `/content/drive`.*

# %%
# !python run_training.py
